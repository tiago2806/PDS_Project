# %%
import pandas as pd

# %%
data = pd.read_csv('city_data.csv', sep = '|', header = 1, index_col = 0)
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 data = pd.read_csv('city_data.csv', sep = '|', header = 1, index_col = 0)
#       2 data
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 data.info()
#
# NameError: name 'data' is not defined

# %%
data[['Working Age Population ', 'GDP per Capita']] = data[['Working Age Population ', 'GDP per Capita']].astype('int')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 84 entries, ('Austria', 'Salzburg') to ('United Kingdom', 'London')
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Population Density               84 non-null     float64
#  1   Population                       84 non-null     int64
#  2   Working Age Population           84 non-null     int64
#  3   Youth Dependency Ratio           84 non-null     float64
#  4   Unemployment Rate                84 non-null     float64
#  5   GDP per Capita                   84 non-null     int64
#  6   Days of very strong heat stress  84 non-null     int64
#  7   Main Spoken Languages            84 non-null     object
#  8   Average Monthly Salary           84 non-null     int64
#  9   Avgerage Rent Price              84 non-null     int64
#  10  Average Cost of Living           84 non-null     int64
# ...

# %%
data.isna().sum()
# Out:
# Population Density                  1
# Population                          0
# Working Age Population              1
# Youth Dependency Ratio              0
# Unemployment Rate                   1
# GDP per Capita                      1
# Days of very strong heat stress     0
# Main Spoken Languages               1
# Average Monthly Salary              0
# Avgerage Rent Price                 0
# Average Cost of Living              0
# Average Price Groceries            80
# Last Data Update                    0
# dtype: int64

# %%
data.drop('Average Price Groceries', axis = 1, inplace = True)
data
# Out:
#                     Population Density  Population  Working Age Population   \
# City
# Vienna, Austria                  310.0     2983513                2018818.0
# Salzburg, Austria                243.0      375489                 250472.0
# Brussels, Belgium                681.0     3284548                2137425.0
# Antwerp, Belgium                 928.0     1139663                 723396.0
# Gent, Belgium                    552.0      645813                 417832.0
# ...                                ...         ...                      ...
# Stockholm, Sweden                334.0     2344124                1534225.0
# Gothenburg, Sweden               245.0     1037675                 672152.0
# Malmo, Sweden                    368.0      680335                 436271.0
# Ankara, Turkiye                 1922.0     4843511                3417691.0
# Adana, Turkiye                   552.0     1074543                 718256.0
#
# ...

# %%
data[data['Main Spoken Languages'].isna()]
# Out:
#                      Population Density  Population  Working Age Population   \
# City
# Dusseldorf, Germany              1295.0     1554077                      NaN
#
#                      Youth Dependency Ratio  Unemployment Rate  \
# City
# Dusseldorf, Germany                    21.4                3.3
#
#                      GDP per Capita  Days of very strong heat stress  \
# City
# Dusseldorf, Germany         71238.0                                3
#
#                     Main Spoken Languages  Average Monthly Salary  \
# City
# Dusseldorf, Germany                   NaN                    3200
#
#                      Avgerage Rent Price  Average Cost of Living  \
# City
# Dusseldorf, Germany                 1100                    2050
#
#                         Last Data Update
# City
# Dusseldorf, Germany  2024-01-15 00:00:00

# %%
data.loc[data.index.str.contains('Germany'), ['Main Spoken Languages']].mode()
# Out:
#   Main Spoken Languages
# 0                German

# %%
data.loc[data.index.str.contains('Germany'), ['Working Age Population ']].mean()
# Out:
# Working Age Population     1840473.0
# dtype: float64

# %%
data.loc['Dusseldorf, Germany', 'Main Spoken Languages'] = 'German'

# %%
data.loc['Dusseldorf, Germany', ['Working Age Population ']] =  data.loc[data.index.str.contains('Germany'), ['Working Age Population ']].mean()

# %% [markdown]
# mean = median so we used mean

# %%
data.loc[['Dusseldorf, Germany'], ['Working Age Population ','Main Spoken Languages']]
# Out:
#                      Working Age Population  Main Spoken Languages
# City
# Dusseldorf, Germany                1840473.0                German

# %%
data.isna().sum()
# Out:
# Population Density                 1
# Population                         0
# Working Age Population             0
# Youth Dependency Ratio             0
# Unemployment Rate                  1
# GDP per Capita                     1
# Days of very strong heat stress    0
# Main Spoken Languages              0
# Average Monthly Salary             0
# Avgerage Rent Price                0
# Average Cost of Living             0
# Last Data Update                   0
# dtype: int64

# %%
#now numerical data

# %%
data.columns
# Out:
# Index(['Population Density', 'Population', 'Working Age Population ',
#        'Youth Dependency Ratio', 'Unemployment Rate', 'GDP per Capita',
#        'Days of very strong heat stress', 'Main Spoken Languages',
#        'Average Monthly Salary', 'Avgerage Rent Price',
#        'Average Cost of Living', 'Last Data Update'],
#       dtype='object')

# %%
data[data['Population Density'].isna()]
# Out:
#                  Population Density  Population  Working Age Population   \
# City
# Valencia, Spain                 NaN     1748142                1162828.0
#
#                  Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# City
# Valencia, Spain                    22.6               13.7         33570.0
#
#                  Days of very strong heat stress Main Spoken Languages  \
# City
# Valencia, Spain                                5     Spanish;Valencian
#
#                  Average Monthly Salary  Avgerage Rent Price  \
# City
# Valencia, Spain                    2400                 1190
#
#                  Average Cost of Living     Last Data Update
# City
# Valencia, Spain                    1300  2023-06-04 00:00:00

# %%
data.loc[data.index.str.contains('Spain')]
# Out:
#                   Population Density  Population  Working Age Population   \
# City
# Madrid, Spain                  873.0     6882461                4617753.0
# Barcelona, Spain              1918.0     5034925                3331345.0
# Valencia, Spain                  NaN     1748142                1162828.0
# Seville, Spain                 330.0     1549641                1037225.0
# Malaga, Spain                  571.0      869096                 585608.0
# Malaga, Spain                  571.0      869096                 585608.0
#
#                   Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# City
# Madrid, Spain                       23.0               10.8         51020.0
# Barcelona, Spain                    22.6               11.0         45016.0
# Valencia, Spain                     22.6               13.7         33570.0
# Seville, Spain                      25.0               21.6         30004.0
# ...

# %%
data.loc[data.index.str.contains('Spain'), ['Population Density']].median()
# Out:
# Population Density    571.0
# dtype: float64

# %%
data.loc['Valencia, Spain', ['Population Density']] =  data.loc[data.index.str.contains('Spain'), ['Population Density']].median()

# %%
data.isna().sum()
# Out:
# Population Density                 0
# Population                         0
# Working Age Population             0
# Youth Dependency Ratio             0
# Unemployment Rate                  1
# GDP per Capita                     1
# Days of very strong heat stress    0
# Main Spoken Languages              0
# Average Monthly Salary             0
# Avgerage Rent Price                0
# Average Cost of Living             0
# Last Data Update                   0
# dtype: int64

# %%
data[data['Unemployment Rate'].isna()]
# Out:
#                Population Density  Population  Working Age Population   \
# City
# Gent, Belgium               552.0      645813                 417832.0
#
#                Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# City
# Gent, Belgium                    24.8                NaN         53311.0
#
#                Days of very strong heat stress Main Spoken Languages  \
# City
# Gent, Belgium                                2         Dutch, French
#
#                Average Monthly Salary  Avgerage Rent Price  \
# City
# Gent, Belgium                    2400                  827
#
#                Average Cost of Living     Last Data Update
# City
# Gent, Belgium                    1200  2023-07-17 00:00:00

# %%
data.loc[data.index.str.contains('Belgium')]
# Out:
#                    Population Density  Population  Working Age Population   \
# City
# Brussels, Belgium               681.0     3284548                2137425.0
# Antwerp, Belgium                928.0     1139663                 723396.0
# Gent, Belgium                   552.0      645813                 417832.0
# Bruges, Belgium                 840.0      119765                  74600.0
#
#                    Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# City
# Brussels, Belgium                   27.50               10.7         62500.0
# Antwerp, Belgium                    27.70                6.2         57595.0
# Gent, Belgium                       24.80                NaN         53311.0
# Bruges, Belgium                     25.63                5.6         63083.0
#
#                    Days of very strong heat stress  \
# City
# Brussels, Belgium                                3
# Antwerp, Belgium                                 3
# ...

# %%
data.loc[data.index.str.contains('Belgium'), ['Unemployment Rate']].median()
# Out:
# Unemployment Rate    6.2
# dtype: float64

# %%
data.loc['Gent, Belgium', ['Unemployment Rate']] =  data.loc[data.index.str.contains('Belgium'), ['Unemployment Rate']].median()

# %%
data.isna().sum()
# Out:
# Population Density                 0
# Population                         0
# Working Age Population             0
# Youth Dependency Ratio             0
# Unemployment Rate                  0
# GDP per Capita                     1
# Days of very strong heat stress    0
# Main Spoken Languages              0
# Average Monthly Salary             0
# Avgerage Rent Price                0
# Average Cost of Living             0
# Last Data Update                   0
# dtype: int64

# %%
data[data['GDP per Capita'].isna()]
# Out:
#                 Population Density  Population  Working Age Population   \
# City
# Lemesos;Cyprus               190.0      262238                 173906.0
#
#                 Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# City
# Lemesos;Cyprus                   23.06               11.2             NaN
#
#                 Days of very strong heat stress    Main Spoken Languages  \
# City
# Lemesos;Cyprus                                0  Greek, English, Russian
#
#                 Average Monthly Salary  Avgerage Rent Price  \
# City
# Lemesos;Cyprus                    2500                 1400
#
#                 Average Cost of Living     Last Data Update
# City
# Lemesos;Cyprus                    2300  2023-08-14 00:00:00

# %%
data.loc[data.index.str.contains('Cyprus')]
# Out:
#                   Population Density  Population  Working Age Population   \
# City
# Lefkosia, Cyprus               130.0      356400                 237000.0
# Lemesos;Cyprus                 190.0      262238                 173906.0
#
#                   Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# City
# Lefkosia, Cyprus                   23.06                9.6         34907.0
# Lemesos;Cyprus                     23.06               11.2             NaN
#
#                   Days of very strong heat stress    Main Spoken Languages  \
# City
# Lefkosia, Cyprus                               45  Greek, Turkish, English
# Lemesos;Cyprus                                  0  Greek, English, Russian
#
#                   Average Monthly Salary  Avgerage Rent Price  \
# City
# Lefkosia, Cyprus                    1486                  700
# Lemesos;Cyprus                      2500                 1400
#
#                   Average Cost of Living     Last Data Update
# ...

# %%
data.loc[data.index.str.contains('Cyprus'), ['GDP per Capita']].mean()
# Out:
# GDP per Capita    34907.0
# dtype: float64

# %%
data.loc['Lemesos;Cyprus', ['GDP per Capita']] =  data.loc[data.index.str.contains('Cyprus'), ['GDP per Capita']].median()

# %%
data.loc[['Lemesos;Cyprus'], ['GDP per Capita']]
# Out:
#                 GDP per Capita
# City
# Lemesos;Cyprus         34907.0

# %%
data.isna().sum()
# Out:
# Population Density                 0
# Population                         0
# Working Age Population             0
# Youth Dependency Ratio             0
# Unemployment Rate                  0
# GDP per Capita                     0
# Days of very strong heat stress    0
# Main Spoken Languages              0
# Average Monthly Salary             0
# Avgerage Rent Price                0
# Average Cost of Living             0
# Last Data Update                   0
# dtype: int64

# %%
data[data.duplicated()==True]
# Out:
#                  Population Density  Population  Working Age Population   \
# City
# Berlin. Germany               304.0     5303922                3481212.0
# Malaga, Spain                 571.0      869096                 585608.0
#
#                  Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# City
# Berlin. Germany                    21.3                4.7         46548.0
# Malaga, Spain                      23.5               17.7         27694.0
#
#                  Days of very strong heat stress  \
# City
# Berlin. Germany                                3
# Malaga, Spain                                  0
#
#                             Main Spoken Languages  Average Monthly Salary  \
# City
# Berlin. Germany  German, Turkish, Arabic, English                    3200
# Malaga, Spain                    Spanish, English                    2200
#
#                  Avgerage Rent Price  Average Cost of Living  \
# City
# ...

# %%
data.drop_duplicates(inplace = True)

# %%
data[['City', 'Country']] = data.index.to_series().str.split(', ', expand=True)


cols = ['Country', 'City'] + [c for c in data.columns if c not in ['Country', 'City']]
data = data[cols]

data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 # separar a coluna City em duas novas colunas
# ----> 2 data[['City', 'Country']] = data.index.to_series().str.split(', ', expand=True)
#       4 # opcional: mover City e Country para o início do dataframe
#       5 cols = ['Country', 'City'] + [c for c in data.columns if c not in ['Country', 'City']]
#
# NameError: name 'data' is not defined
